# %%
import nbformat

path = "pid_controller.ipynb"  # adjust if you cloned the repo
nb = nbformat.read(path, as_version=4)

print("Top-level metadata keys:", nb["metadata"].keys())
if "widgets" in nb["metadata"]:
    print("🚨 widgets metadata is still there!")
    print(nb["metadata"]["widgets"].keys())
else:
    print("✅ no widgets metadata found")
# Out:
# Top-level metadata keys: dict_keys(['colab', 'kernelspec', 'language_info', 'widgets'])
# 🚨 widgets metadata is still there!
# dict_keys(['application/vnd.jupyter.widget-state+json'])

# %%
import nbformat

path = "pid_controller.ipynb"  # adjust if your file is somewhere else

# Load the notebook
nb = nbformat.read(path, as_version=4)

# Remove the widgets metadata entirely
if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]
    print("🚨 Removed 'widgets' metadata")

# Save the cleaned notebook
nbformat.write(nb, path)
print("✅ Notebook saved without widgets metadata")
# Out:
# 🚨 Removed 'widgets' metadata
# ✅ Notebook saved without widgets metadata

# %%
nb = nbformat.read(path, as_version=4)
print("Top-level metadata keys:", nb["metadata"].keys())
# Out:
# Top-level metadata keys: dict_keys(['colab', 'kernelspec', 'language_info'])
