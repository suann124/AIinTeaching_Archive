# %% [markdown]
# # Lecture 1: Introduction to Control Systems
#
# ## Learning Objectives
# - Understand what control systems are and why they're important
# - Learn about open-loop vs closed-loop systems
# - Introduction to feedback control
#
# ## What is a Control System?
#
# A control system is a system that manages, commands, directs, or regulates the behavior of other devices or systems using control loops.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simple example: Temperature control
print("Welcome to Control Systems!")
print("In this lecture, we'll explore the fundamentals of control theory.")

# %% [markdown]
# ## Exercise 1.1
# Think of three control systems you encounter in daily life. For each one, identify:
# 1. What is being controlled?
# 2. What is the desired output?
# 3. How does the system measure its performance?

# %%
# TODO: Write your answers here as comments
# Example 1: 
# Example 2:
# Example 3:
