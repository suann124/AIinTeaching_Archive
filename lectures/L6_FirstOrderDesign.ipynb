# %% [markdown]
# <a href="https://colab.research.google.com/github/suann124/AIinTeaching/blob/main/L6_FirstOrderDesign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Make your edit here

# %%
print("Testing testing 1,2,3...")
# Out:
# Testing testing 1,2,3...
